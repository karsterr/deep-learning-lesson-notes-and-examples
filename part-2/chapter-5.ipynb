# %% [markdown]
# ## 📌 Chapter 5 – Project: Develop Large Models on GPUs Cheaply in the Cloud (Özet)
#
# ### 5.1 Project Overview
#
# * Büyük derin öğrenme modelleri CPU’da çok yavaş → saatler hatta günler sürebilir.
# * GPU ile hız büyük ölçüde artıyor.
# * Amazon Web Services (AWS) üzerinden GPU kiralayarak bu işi **ucuz ve hızlı** yapmak mümkün.
# * Adımlar:
#
#   1. AWS hesabı açmak.
#   2. GPU destekli bir EC2 instance başlatmak.
#   3. Keras, Theano/TensorFlow kurulu hazır AMI imajını kullanmak.
#   4. Kodlarını çalıştırmak.
#   5. İş bitince instance’ı kapatmak (yoksa ücret işlemeye devam eder).
#
# ### 5.2 Setup Your AWS Account
#
# * AWS hesabı açılır, kredi kartı bilgisi eklenir.
# * AWS Console üzerinden servislere erişim sağlanır.
#
# ### 5.3 Launch Your Server Instance
#
# * **EC2 (Elastic Compute Cloud)** → sanal sunucu servisi.
# * GPU destekli donanım seçilir (ör: `g2.2xlarge`).
# * Stanford CS231n dersine ait hazır AMI (örn. `ami-125b2c72`) kullanılabilir.
# * SSH key pair (anahtar çifti) ile güvenli giriş yapılır.
#
# ### 5.4 Login, Configure and Run
#
# * Terminalden `ssh -i key.pem ubuntu@<IP>` ile bağlanılır.
# * Gerekirse Keras/Theano sürümleri güncellenir.
# * Theano config dosyasında GPU kullanımı aktif hale getirilir.
# * Kurulum test edilir (`import keras`, `import theano`).
#
# ### 5.5 Build and Run Models on AWS
#
# * Kodlar `scp` ile sunucuya kopyalanabilir.
# * Eğitimler uzun süreceği için `nohup` ile arka planda çalıştırmak önerilir.
# * Log dosyaları üzerinden ilerleme takip edilir.
#
# ### 5.6 Close Your EC2 Instance
#
# * İş bitince **mutlaka** instance kapatılır (terminate).
# * Aksi halde ücret işlemeye devam eder.
#
# ### 5.7 Tips and Tricks
#
# * Deneyleri önceden planla, boşuna GPU süresi yakma.
# * Spot Instances kullan → daha ucuz ama aniden kapanabilir.
# * Düzenli olarak verilerini ve sonuçlarını yedekle.
#
# ### 5.8 More Resources
#
# * AWS resmi dokümantasyonu, deep learning için hazır kaynaklar listelenmiş.
